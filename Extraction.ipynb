# %% [markdown]
# <a href="https://colab.research.google.com/github/Iman005/Machine-Learning/blob/main/Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("housing.csv")

# %%
train_set,test_set=train_test_split(df,test_size=0.2,random_state=40)

# %%
df["median_income_categories"]=pd.cut(df["median_income"],bins=[0.0,1.5,3.0,4.5,6.0,np.inf],labels=[1,2,3,4,5])

# %% [markdown]
# "Defining the necessary specifications and visualizing valuable data for the project."

# %%
df["median_income_categories"].value_counts().sort_index().plot.bar(grid=True)
# Out:
# <Axes: xlabel='median_income_categories'>
