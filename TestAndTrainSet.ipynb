# %% [markdown]
# <a href="https://colab.research.google.com/github/Iman005/Machine-Learning/blob/main/TestAndTrainSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("housing.csv")

# %%
def suffle_and_split_df(df,ratio):
  random_indices=np.random.permutation(len(df))
  test_set_size=int(len(df)*ratio)
  test_random_indices=random_indices[:test_set_size]
  train_random_indices=random_indices[test_set_size:]
  return df.iloc[train_random_indices] , df.iloc[test_random_indices]

# %%
train_set,test_set=suffle_and_split_df(df,0.2)

# %%
train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16148    -122.47     37.78                52.0       2042.0           378.0
# 10078    -120.27     39.35                11.0       2520.0           401.0
# 4718     -118.38     34.06                31.0       4345.0          1158.0
# 16165    -122.50     37.77                52.0       2739.0           569.0
# 813      -122.03     37.61                36.0       1409.0           271.0
# ...          ...       ...                 ...          ...             ...
# 2360     -119.63     36.70                42.0       1338.0           215.0
# 5593     -118.25     33.80                36.0       1697.0           394.0
# 1939     -120.95     38.69                10.0       3421.0           563.0
# 10620    -117.82     33.67                17.0       2895.0           439.0
# 12941    -121.26     38.65                17.0       2655.0           421.0
#
# ...

# %%
test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11281    -117.95     33.79                34.0       2584.0           408.0
# 113      -122.25     37.83                52.0       2376.0           559.0
# 4970     -118.28     34.01                52.0        795.0           308.0
# 924      -121.92     37.49                10.0       7441.0          1588.0
# 3275     -122.92     39.05                38.0       3131.0           624.0
# ...          ...       ...                 ...          ...             ...
# 9385     -122.47     37.89                23.0      10774.0          1736.0
# 15692    -122.44     37.79                52.0       2045.0           353.0
# 14611    -117.18     32.80                30.0       2456.0           390.0
# 3697     -118.37     34.20                34.0       2199.0           609.0
# 3811     -118.47     34.20                20.0       3939.0          1143.0
#
# ...

# %% [markdown]
# **The current approach for splitting the data into training and test sets is suboptimal. This is because we do not want the results to be affected by different random values each time the code is executed. Although one possible workaround is to save the generated sets and reuse the saved file, this solution is also limited—especially if we intend to modify the dataset in the future. Therefore, a more robust and reliable method is required, which we will introduce in the following section.**
